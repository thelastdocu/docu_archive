# %% [markdown]
# df['vod_key']가 news noun으로 뽑은 태그임

# %%
import pandas as pd
df= pd.read_csv('final_song_oc.csv',encoding='cp949')
df
# Out:
#         id   tv    title                                          epi  \
# 0        1  SBS  SBS 스페셜                       그랜드 슬램 대탐험  걸어서 지구 끝까지
# 1        2  SBS  SBS 스페셜                             꿈을 쏘다! - 박주영 박지성
# 2        3  SBS  SBS 스페셜               메이드 인 코리아 1부 - 광복 60년 한국인들의 위상
# 3        4  SBS  SBS 스페셜                         메이드 인 코리아 2부 - 한국천재들
# 4        5  SBS  SBS 스페셜                        메이드 인 코리아 3부 - 한국인의 손
# 5        6  SBS  SBS 스페셜                    메이드 인 코리아 4부 - 한류  명품이 되다
# 6        7  SBS  SBS 스페셜                     메이드 인 코리아 5부 - 빨리 빨리 한국인
# 7        8  SBS  SBS 스페셜                     메이드 인 코리아 6부 - 주식회사 대한민국
# 8        9  SBS  SBS 스페셜         광복 60주년 SBS스페셜  조용필  평양에서 부르는 꿈의 아리랑
# 9       10  SBS  SBS 스페셜                           나는 가요, 도쿄 제2학교의 여름
# 10      11  SBS  SBS 스페셜                          젖과 꿀 흐르는 땅  유대인의 미국
# 11      12  SBS  SBS 스페셜                                 깨어나는 이슬람의 딸들
# ...

# %%
df.fillna(0)
# Out:
#         id   tv    title                                          epi  \
# 0        1  SBS  SBS 스페셜                       그랜드 슬램 대탐험  걸어서 지구 끝까지
# 1        2  SBS  SBS 스페셜                             꿈을 쏘다! - 박주영 박지성
# 2        3  SBS  SBS 스페셜               메이드 인 코리아 1부 - 광복 60년 한국인들의 위상
# 3        4  SBS  SBS 스페셜                         메이드 인 코리아 2부 - 한국천재들
# 4        5  SBS  SBS 스페셜                        메이드 인 코리아 3부 - 한국인의 손
# 5        6  SBS  SBS 스페셜                    메이드 인 코리아 4부 - 한류  명품이 되다
# 6        7  SBS  SBS 스페셜                     메이드 인 코리아 5부 - 빨리 빨리 한국인
# 7        8  SBS  SBS 스페셜                     메이드 인 코리아 6부 - 주식회사 대한민국
# 8        9  SBS  SBS 스페셜         광복 60주년 SBS스페셜  조용필  평양에서 부르는 꿈의 아리랑
# 9       10  SBS  SBS 스페셜                           나는 가요, 도쿄 제2학교의 여름
# 10      11  SBS  SBS 스페셜                          젖과 꿀 흐르는 땅  유대인의 미국
# 11      12  SBS  SBS 스페셜                                 깨어나는 이슬람의 딸들
# ...

# %%
df.fillna('', inplace=True)

# %%
# 대분류 안에서 정치 사회를 년도 별로 보기
ps = df[df['대분류'].str.contains('정치/사회')]
ps
# Out:
#         id   tv    title                                  epi       dates  \
# 24      25  SBS  SBS 스페셜            한국을 떠난 사람들 - 그들이 말하는 대한민국  2006-01-22
# 55      56  SBS  SBS 스페셜       탈북자(1부) 이용운 일가의 북한 탈출, 그 후 10년  2006-11-12
# 56      57  SBS  SBS 스페셜                탈북자(2부) 달래음악단의 그날이 오면  2006-11-19
# 164    165  SBS  SBS 스페셜                 길을 찾는 사람들 - 휴메니버시티 -  2008-09-21
# 200    201  MBC  MBC 스페셜                         아무도 묻지 않은 죽음  2009-02-15
# 227    228  SBS  SBS 스페셜                     88만원 세대의 힘겨운 데뷔전  2009-04-05
# 290    291  EBS    다큐프라임          햄버거 커넥션  제1부 <햄버거의 패티, 열대림>  2009-08-31
# 291    292  EBS    다큐프라임       햄버거 커넥션  제2부 <새로운 커넥션, 브라질 대두>  2009-09-01
# 292    293  EBS    다큐프라임           햄버거 커넥션  제3부 <최후의 커넥션, 지구>  2009-09-02
# 313    314  MBC  MBC 스페셜                    취업난이 우리 삶에 끼치는 영향  2009-10-09
# 350    351  EBS    다큐프라임  <아동범죄, 미스터리의 과학>1부 아이들은 왜 낯선 사람을 따라  2009-12-14
# 351    352  EBS    다큐프라임    <아동범죄, 미스터리의 과학>2부 아동성범죄자, 그들은 누구  2009-12-15
# ...

# %%
df["year"] = df.dates.apply(lambda x : x.split('-')[0]) # 년도 별로 나누기
df["month"] = df.dates.apply(lambda x : x.split('-')[1]) # 달로 나누기
df['month']= df['month'].astype(int)
df['year']= df['year'].astype(int)
df
# Out:
#         id   tv    title                                          epi  \
# 0        1  SBS  SBS 스페셜                       그랜드 슬램 대탐험  걸어서 지구 끝까지
# 1        2  SBS  SBS 스페셜                             꿈을 쏘다! - 박주영 박지성
# 2        3  SBS  SBS 스페셜               메이드 인 코리아 1부 - 광복 60년 한국인들의 위상
# 3        4  SBS  SBS 스페셜                         메이드 인 코리아 2부 - 한국천재들
# 4        5  SBS  SBS 스페셜                        메이드 인 코리아 3부 - 한국인의 손
# 5        6  SBS  SBS 스페셜                    메이드 인 코리아 4부 - 한류  명품이 되다
# 6        7  SBS  SBS 스페셜                     메이드 인 코리아 5부 - 빨리 빨리 한국인
# 7        8  SBS  SBS 스페셜                     메이드 인 코리아 6부 - 주식회사 대한민국
# 8        9  SBS  SBS 스페셜         광복 60주년 SBS스페셜  조용필  평양에서 부르는 꿈의 아리랑
# 9       10  SBS  SBS 스페셜                           나는 가요, 도쿄 제2학교의 여름
# 10      11  SBS  SBS 스페셜                          젖과 꿀 흐르는 땅  유대인의 미국
# 11      12  SBS  SBS 스페셜                                 깨어나는 이슬람의 딸들
# ...

# %%
ps_2017 = ps[ps['year'].str.contains('2017')]
ps_2017
# Out:
#         id   tv    title                               epi       dates  \
# 1534  1535  MBC  MBC 스페셜                       나 혼자'먹고' 산다  2017-01-02
# 1536  1537  KBS  KBS 스페셜  행복한 국가를 만든 리더십(2)스웨덴을 구한 섬김의 리더십  2017-01-12
# 1542  1543  SBS  SBS 스페셜                          대통령의 탄생   2017-02-05
# 1545  1546  KBS  KBS 스페셜                             블랙리스트  2017-02-09
# 1546  1547  KBS  KBS 스페셜                 북핵 위기 - 기로에 선 한반도  2017-02-10
# 1547  1548  KBS  KBS 스페셜     뉴 메이드 인 코리아 - 축적의 시간(1)착각의 시간  2017-02-14
# 1548  1549  SBS  SBS 스페셜                           시크릿 공화국  2017-02-19
# 1552  1553  EBS    다큐프라임            <2017 시대탐구 청년> 2부 최저인생  2017-02-28
# 1556  1557  KBS  KBS 스페셜                         3년,세월의 시간  2017-03-05
# 1557  1558  EBS    다큐프라임         <2017 시대탐구 청년> 3부 평범하고 싶다  2017-03-06
# 1559  1560  EBS    다큐프라임        <2017 시대탐구 청년> 4부 할 수 있을까?  2017-03-07
# 1561  1562  SBS  SBS 스페셜                      사건번호 2016헌나1  2017-03-12
# ...

# %%
ps = df[df['대분류'].str.contains('정치/사회')]
ps
# Out:
#         id   tv    title                                  epi       dates  \
# 24      25  SBS  SBS 스페셜            한국을 떠난 사람들 - 그들이 말하는 대한민국  2006-01-22
# 55      56  SBS  SBS 스페셜       탈북자(1부) 이용운 일가의 북한 탈출, 그 후 10년  2006-11-12
# 56      57  SBS  SBS 스페셜                탈북자(2부) 달래음악단의 그날이 오면  2006-11-19
# 164    165  SBS  SBS 스페셜                 길을 찾는 사람들 - 휴메니버시티 -  2008-09-21
# 200    201  MBC  MBC 스페셜                         아무도 묻지 않은 죽음  2009-02-15
# 227    228  SBS  SBS 스페셜                     88만원 세대의 힘겨운 데뷔전  2009-04-05
# 290    291  EBS    다큐프라임          햄버거 커넥션  제1부 <햄버거의 패티, 열대림>  2009-08-31
# 291    292  EBS    다큐프라임       햄버거 커넥션  제2부 <새로운 커넥션, 브라질 대두>  2009-09-01
# 292    293  EBS    다큐프라임           햄버거 커넥션  제3부 <최후의 커넥션, 지구>  2009-09-02
# 313    314  MBC  MBC 스페셜                    취업난이 우리 삶에 끼치는 영향  2009-10-09
# 350    351  EBS    다큐프라임  <아동범죄, 미스터리의 과학>1부 아이들은 왜 낯선 사람을 따라  2009-12-14
# 351    352  EBS    다큐프라임    <아동범죄, 미스터리의 과학>2부 아동성범죄자, 그들은 누구  2009-12-15
# ...

# %%
ps['year'] = ps['year'].astype(str)
# Out:
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
ps_2018 = ps[ps['year'].str.contains('2018')]
ps_2017 = ps[ps['year'].str.contains('2017')]
ps_2016 = ps[ps['year'].str.contains('2016')]
ps_2015 = ps[ps['year'].str.contains('2015')]


ps_2016
# Out:
#         id   tv    title                                    epi       dates  \
# 1365  1366  SBS  SBS 스페셜                  졸업 - 학교를 떠날 수 없는 아이들   2016-02-28
# 1369  1370  SBS  SBS 스페셜            아빠 찾는 게 죄인가요? - 코피노의 마지막 선택  2016-03-06
# 1372  1373  KBS  KBS 스페셜                      트럼프 돌풍 - 워싱턴을 흔들다  2016-03-12
# 1373  1374  SBS  SBS 스페셜                        아저씨, 어쩌다 보니 개저씨  2016-03-13
# 1374  1375  EBS    다큐프라임                    천국의 아이들 - 1부 나디아의 산  2016-03-14
# 1376  1377  EBS    다큐프라임                 천국의 아이들 - 2부 웰컴 투 해피랜드  2016-03-15
# 1377  1378  EBS    다큐프라임              천국의 아이들 - 3부 찰스, 코트 앞에 서다  2016-03-16
# 1381  1382  KBS  KBS 스페셜                       한 · 중 · 일 벤처 삼국지  2016-03-24
# 1382  1383  KBS  KBS 스페셜                                 저성장의 덫  2016-03-25
# 1383  1384  SBS  SBS 스페셜                  두여자의 고백 - 럭셔리블로거의 그림자  2016-03-27
# 1387  1388  KBS  KBS 스페셜                              저유가의 패러독스  2016-03-31
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(analyzer = 'word', # 캐릭터 단위로 벡터화 할 수도 있습니다.
                             tokenizer = None, # 토크나이저를 따로 지정해 줄 수도 있습니다.
                             preprocessor = None, # 전처리 도구
                             stop_words = None, # 불용어 nltk등의 도구를 사용할 수도 있습니다.
                             min_df = 2, # 토큰이 나타날 최소 문서 개수로 오타나 자주 나오지 않는 특수한 전문용어 제거에 좋다. 
                             ngram_range=(1, 3), # BOW의 단위를 1~3개로 지정합니다.
                             max_features = 1000 # 만들 피처의 수, 단어의 수가 된다.
                            )
vectorizer
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=1000, min_df=2,
#         ngram_range=(1, 3), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
# import re
# p = r'.*(대통령|한나라당|민주당|국회|정당).*'
# politic = df[df['epi'].str.match(p) |
#            df['vod_key'].str.match(p, flags=re.MULTILINE)]
# politic.shape
# Out:
# (22, 12)

# %%
# ps = df[df['대분류'].str.contains('정치/사회')]
# ps
# Out:
#   File "<ipython-input-29-742a1fbe1e6c>", line 2
#     politics
#            ^
# SyntaxError: invalid syntax

# %%
ps_2017
# Out:
#         id   tv    title                               epi       dates  \
# 1534  1535  MBC  MBC 스페셜                       나 혼자'먹고' 산다  2017-01-02
# 1536  1537  KBS  KBS 스페셜  행복한 국가를 만든 리더십(2)스웨덴을 구한 섬김의 리더십  2017-01-12
# 1542  1543  SBS  SBS 스페셜                          대통령의 탄생   2017-02-05
# 1545  1546  KBS  KBS 스페셜                             블랙리스트  2017-02-09
# 1546  1547  KBS  KBS 스페셜                 북핵 위기 - 기로에 선 한반도  2017-02-10
# 1547  1548  KBS  KBS 스페셜     뉴 메이드 인 코리아 - 축적의 시간(1)착각의 시간  2017-02-14
# 1548  1549  SBS  SBS 스페셜                           시크릿 공화국  2017-02-19
# 1552  1553  EBS    다큐프라임            <2017 시대탐구 청년> 2부 최저인생  2017-02-28
# 1556  1557  KBS  KBS 스페셜                         3년,세월의 시간  2017-03-05
# 1557  1558  EBS    다큐프라임         <2017 시대탐구 청년> 3부 평범하고 싶다  2017-03-06
# 1559  1560  EBS    다큐프라임        <2017 시대탐구 청년> 4부 할 수 있을까?  2017-03-07
# 1561  1562  SBS  SBS 스페셜                      사건번호 2016헌나1  2017-03-12
# ...

# %%
def preprocessing(text):
    # 개행문자 제거
    text = re.sub('\\\\n', ' ', text)
    # 특수문자 제거
    # 특수문자나 이모티콘 등은 때로는 의미를 갖기도 하지만 여기에서는 제거했습니다.
    # text = re.sub('[?.,;:|\)*~`’!^\-_+<>@\#$%&-=#}※]', '', text)
    # 한글, 영문, 숫자만 남기고 모두 제거하도록 합니다.
    # text = re.sub('[^가-힣ㄱ-ㅎㅏ-ㅣa-zA-Z0-9]', ' ', text)
    # 한글, 영문만 남기고 모두 제거하도록 합니다.
    text = re.sub('[^가-힣ㄱ-ㅎㅏ-ㅣa-zA-Z]', ' ', text)
    return text

# %%
# %time ps_2018['content_preprocessing'] = ps_2018['vod_key'].apply(preprocessing)
# sentences = ps_2018['content_preprocessing']
# sentences.shape
# Out:
# Wall time: 36.9 ms
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# (24,)

# %%
# %time ps_2016['content_preprocessing'] = ps_2016['vod_key'].apply(preprocessing)
sentences = ps_2016['content_preprocessing']
sentences.shape
# Out:
# Wall time: 36.9 ms
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# (40,)

# %%
# %%time 
feature_vector = vectorizer.fit_transform(ps_2016['content_preprocessing'])
feature_vector.shape
# Out:
# Wall time: 4.47 ms

# %%
# %%time 
# feature_vector2 = vectorizer.fit_transform(ps_2017['content_preprocessing'])
# feature_vector2.shape
# Out:
# Wall time: 4.49 ms

# %%
vocab = vectorizer.get_feature_names()
print(len(vocab))
vocab[:10]
# Out:
# 21
# ['xa', '그녀', '기억', '남성', '대한민국', '매립장', '민주주의', '사람들', '사회', '세상']

# %%
#2017년도
# vocab = vectorizer.get_feature_names()
# print(len(vocab))
# vocab[:10]
# Out:
# 18
# ['결정', '국민', '대통령', '대통령 국민', '대통령 선거', '대통령 탄핵', '대한민국', '미국', '사람들', '선거']

# %%
#2018
# import numpy as np
# dist = np.sum(feature_vector, axis=0)
    
# for tag, count in zip(vocab, dist):
#     print(count, tag)
    
# pd.DataFrame(dist, columns=vocab)
# Out:
# [[2 2 2 4 2 2 2 3 3]] 김정은
#    김정은  모습  바다  북한  사람들  우리  이야기  평양  한반도
# 0    2   2   2   4    2   2    2   3    3

# %%
# 2015년
dist = np.sum(feature_vector, axis=0)
    
for tag, count in zip(vocab, dist):
    print(count, tag)
    
pd.DataFrame(dist, columns=vocab)
# Out:
# [[3 3 3 2 2 2 3]] 공간
#    공간  방송  사람들  살기  시간  시간 공간  아파트
# 0   3   3    3   2   2      2    3

# %%
#2016년
dist = np.sum(feature_vector, axis=0)
    
for tag, count in zip(vocab, dist):
    print(count, tag)
    
pd.DataFrame(dist, columns=vocab)
# Out:
# [[2 3 2 2 2 2 4 2 5 4 2 2 3 2 2 4 2 2 2 3 2]] xa
#    xa  그녀  기억  남성  대한민국  매립장  민주주의  사람들  사회  세상 ...  시대  쓰레기  쓰레기 매립장  아이  \
# 0   2   3   2   2     2    2     4    2   5   4 ...   2    3        2   2
#
#    아이들  아이들 세상  아저씨  이들  자신  희망
# 0    4       2    2   2   3   2
#
# [1 rows x 21 columns]

# %%
ps_2018_key = ps_2018['vod_key'].values.tolist()
ps_2018_key
# Out:
# ["'사회', '용기', '자신', '말하기', '세상', '피해자', '이야기', '일본', '우리'",
#  '',
#  '',
#  "'거짓말', '진실', '위증', '처벌', '우리', '국회'",
#  "'백성', '조기', '사람들', '마리', '바다'",
#  "'세월호', '아이', '부모들', '그들', '아픔', '이들', '아이들', '합창단', '처음', '창현이'",
#  '',
#  "'평화', '한반도', '김정은', '북한', '모습', '중국', '스위스', '행보', '방문'",
#  '',
#  "'한반도', '그날', '세계', '판문점', '비무장지대'",
#  '',
#  "'김정은', '장마당', '북한', '변화', '시장', '인민들', '사람들'",
#  "'목포', '수색', '크레인', '바다', '진행', '사진', '가슴', '마음', '얘기', '아들', '건우'",
#  "'트럼프', '미국', '북한', '지도자', '공통점', '협상', '최고', '거래', '협상가'",
#  '',
#  '',
#  "'인간'",
#  '',
#  "'평양', '평양냉면', '냉면', '냉면집', '옥류관'",
#  "'경계'",
#  "'3세', '전무', '갑질', '재벌', '수행기사', '사건', '강유미', '내용', '부사장', '1등석', '실험'",
#  '',
#  "'이산', '이산가족', '상봉', '행사', '70년', '길자', '평양', '고향', '기억', '부모님', '모습', '큰딸'",
#  "'한반도', '북한', '이야기', '의사', '환자들', '치료', '다큐멘터리', '병원', '방송', '한국어', '평양', '린튼', '모두', '순간'"]

# %%
sentences2018 = ps_2018['vod_key'].str.replace('\'','')

# %%
# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'

# 나눔고딕 설치
# !apt -qq -y install fonts-nanum > /dev/null
import matplotlib.font_manager as fm
fontpath = 'NanumGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
# Out:
# 지정된 경로를 찾을 수 없습니다.

# %%
Stopwords = {'사람들','자신','우리','그들','이들','무엇','지금','프로젝트','생각',
             '정도','공동제작','당신','의미','마음','이곳','EBS','NRK','당시','마지막',
             '상황','스스','때문','방법','실제','대상','이야기','3부','4부','프로그램',
             '제작','모습','그것','누구', '모두', '그날', '1등석' '그날', '말하기', '처음', '길자','xa0' , 'n', '사회'}

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline
def displayWordCloud(data = None, backgroundcolor = 'white', width=800, height=600 ):
    wordcloud = WordCloud(
                        font_path = fontpath,
                        stopwords = Stopwords, 
                        background_color = backgroundcolor, 
                         width = width, height = height).generate(data)
    plt.figure(figsize = (15 , 10))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

# %%
# %time displayWordCloud(''.join(sentences2018))
# Out:
# Wall time: 1.72 s

# %%
sentences2017 = ps_2017['vod_key'].str.replace('\'','')

# %%
# %time displayWordCloud(''.join(sentences2017))
# Out:
# Wall time: 1.74 s

# %%
sentences2016 = ps_2016['vod_key'].str.replace('\'','')

# %%
'xa0' , 'n', '사회', ''

# %%
# %time displayWordCloud(''.join(sentences2016))
# Out:
# Wall time: 2.38 s

# %%
sentences2015 = ps_2015['vod_key'].str.replace('\'','')

# %%
# %time displayWordCloud(''.join(sentences2015))
# Out:
# Wall time: 1.5 s
